# %% [markdown]
# # Learning Paradigms Overview
#
# ## Unsupervised Learning - Association

# %% [markdown]
# ### Association Rule Mining Using FP Growth Algorithm

# %%
#import libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules,apriori

# %%
#get data
dataset = pd.read_csv("supermarket.csv")
dataset.head()
# Out:
#   department1 department2 department3 department4 department5 department6  \
# 0           ?           ?           ?           ?           ?           ?
# 1           t           ?           ?           ?           ?           ?
# 2           ?           ?           ?           ?           ?           ?
# 3           t           ?           ?           ?           ?           ?
# 4           ?           ?           ?           ?           ?           ?
#
#   department7 department8 department9 'grocery misc'  ... department208  \
# 0           ?           ?           ?              ?  ...             ?
# 1           ?           ?           ?              ?  ...             ?
# 2           ?           ?           ?              ?  ...             ?
# 3           ?           ?           ?              ?  ...             ?
# 4           ?           ?           ?              ?  ...             ?
#
#   department209 department210 department211 department212 department213  \
# ...

# %%
dataset = dataset.replace('?',False)
dataset = dataset.replace('t',True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8452\581641966.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace('?',False)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8452\581641966.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace('t',True)

# %%
dataset.head()
# Out:
#    department1  department2  department3  department4  department5  \
# 0        False        False        False        False        False
# 1         True        False        False        False        False
# 2        False        False        False        False        False
# 3         True        False        False        False        False
# 4        False        False        False        False        False
#
#    department6  department7  department8  department9  'grocery misc'  ...  \
# 0        False        False        False        False           False  ...
# 1        False        False        False        False           False  ...
# 2        False        False        False        False           False  ...
# 3        False        False        False        False           False  ...
# 4        False        False        False        False           False  ...
#
#    department208  department209  department210  department211  department212  \
# ...

# %%
#One hot encoding for total 
one_hot_total = pd.get_dummies(dataset['total'])
dataset = pd.concat([dataset,one_hot_total],axis =1)
dataset = dataset.drop('total',axis =1)
dataset.head()
# Out:
#    department1  department2  department3  department4  department5  \
# 0        False        False        False        False        False
# 1         True        False        False        False        False
# 2        False        False        False        False        False
# 3         True        False        False        False        False
# 4        False        False        False        False        False
#
#    department6  department7  department8  department9  'grocery misc'  ...  \
# 0        False        False        False        False           False  ...
# 1        False        False        False        False           False  ...
# 2        False        False        False        False           False  ...
# 3        False        False        False        False           False  ...
# 4        False        False        False        False           False  ...
#
#    department209  department210  department211  department212  department213  \
# ...

# %%
dataset = dataset.replace(0,False)
dataset = dataset.replace(1,True)
dataset.head()
# Out:
#    department1  department2  department3  department4  department5  \
# 0        False        False        False        False        False
# 1         True        False        False        False        False
# 2        False        False        False        False        False
# 3         True        False        False        False        False
# 4        False        False        False        False        False
#
#    department6  department7  department8  department9  'grocery misc'  ...  \
# 0        False        False        False        False           False  ...
# 1        False        False        False        False           False  ...
# 2        False        False        False        False           False  ...
# 3        False        False        False        False           False  ...
# 4        False        False        False        False           False  ...
#
#    department209  department210  department211  department212  department213  \
# ...

# %% [markdown]
# ##### FP Growth

# %%
#obtaining frequent itemsets using FPGrowth
frequent_itemsets1 = fpgrowth(dataset, min_support=0.5, use_colnames=True)

# %%
frequent_itemsets1
# Out:
#      support                        itemsets
# 0   0.719689              ('bread and cake')
# 1   0.640156                         (fruit)
# 2   0.639939                    (vegetables)
# 3   0.635185                    (milk-cream)
# 4   0.604063                ('baking needs')
# 5   0.587206                ('frozen foods')
# 6   0.563000                      (biscuits)
# 7   0.532310             (juice-sat-cord-ms)
# 8   0.503566           ('party snack foods')
# 9   0.637130                           (low)
# 10  0.502485       ('bread and cake', fruit)
# 11  0.505079  ('bread and cake', milk-cream)

# %%
rules_by_lift1 = association_rules(frequent_itemsets1,metric="lift",min_threshold=0.8)
rules_by_lift1.shape
# Out:
# (4, 10)

# %%
rules_by_lift1
# Out:
#           antecedents         consequents  antecedent support  \
# 0  ('bread and cake')             (fruit)            0.719689
# 1             (fruit)  ('bread and cake')            0.640156
# 2  ('bread and cake')        (milk-cream)            0.719689
# 3        (milk-cream)  ('bread and cake')            0.635185
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.640156  0.502485    0.698198  1.090670  0.041773    1.192320
# 1            0.719689  0.502485    0.784943  1.090670  0.041773    1.303425
# 2            0.635185  0.505079    0.701802  1.104878  0.047944    1.223398
# 3            0.719689  0.505079    0.795168  1.104878  0.047944    1.368496
#
#    zhangs_metric
# 0       0.296570
# 1       0.231022
# 2       0.338634
# 3       0.260194

# %%
rules_by_conf1 = association_rules(frequent_itemsets1,metric="confidence",min_threshold=0.6)
rules_by_conf1
# Out:
#           antecedents         consequents  antecedent support  \
# 0  ('bread and cake')             (fruit)            0.719689
# 1             (fruit)  ('bread and cake')            0.640156
# 2  ('bread and cake')        (milk-cream)            0.719689
# 3        (milk-cream)  ('bread and cake')            0.635185
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.640156  0.502485    0.698198  1.090670  0.041773    1.192320
# 1            0.719689  0.502485    0.784943  1.090670  0.041773    1.303425
# 2            0.635185  0.505079    0.701802  1.104878  0.047944    1.223398
# 3            0.719689  0.505079    0.795168  1.104878  0.047944    1.368496
#
#    zhangs_metric
# 0       0.296570
# 1       0.231022
# 2       0.338634
# 3       0.260194

# %% [markdown]
# ##### Using Apriori Method

# %%
frequent_itemsets2 = apriori(dataset, min_support=0.5, use_colnames=True)
frequent_itemsets2
# Out:
#      support                        itemsets
# 0   0.719689              ('bread and cake')
# 1   0.604063                ('baking needs')
# 2   0.532310             (juice-sat-cord-ms)
# 3   0.563000                      (biscuits)
# 4   0.587206                ('frozen foods')
# 5   0.503566           ('party snack foods')
# 6   0.635185                    (milk-cream)
# 7   0.640156                         (fruit)
# 8   0.639939                    (vegetables)
# 9   0.637130                           (low)
# 10  0.505079  ('bread and cake', milk-cream)
# 11  0.502485       ('bread and cake', fruit)

# %%
rules_by_lift2 = association_rules(frequent_itemsets2,metric="lift",min_threshold=0.8)
rules_by_lift2.shape
# Out:
# (4, 10)

# %%
rules_by_lift2
# Out:
#           antecedents         consequents  antecedent support  \
# 0  ('bread and cake')        (milk-cream)            0.719689
# 1        (milk-cream)  ('bread and cake')            0.635185
# 2  ('bread and cake')             (fruit)            0.719689
# 3             (fruit)  ('bread and cake')            0.640156
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.635185  0.505079    0.701802  1.104878  0.047944    1.223398
# 1            0.719689  0.505079    0.795168  1.104878  0.047944    1.368496
# 2            0.640156  0.502485    0.698198  1.090670  0.041773    1.192320
# 3            0.719689  0.502485    0.784943  1.090670  0.041773    1.303425
#
#    zhangs_metric
# 0       0.338634
# 1       0.260194
# 2       0.296570
# 3       0.231022

# %%
rules_by_conf2 = association_rules(frequent_itemsets2,metric="confidence",min_threshold=0.6)
rules_by_conf2.shape
# Out:
# (4, 10)

# %%
rules_by_conf2
# Out:
#           antecedents         consequents  antecedent support  \
# 0  ('bread and cake')        (milk-cream)            0.719689
# 1        (milk-cream)  ('bread and cake')            0.635185
# 2  ('bread and cake')             (fruit)            0.719689
# 3             (fruit)  ('bread and cake')            0.640156
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.635185  0.505079    0.701802  1.104878  0.047944    1.223398
# 1            0.719689  0.505079    0.795168  1.104878  0.047944    1.368496
# 2            0.640156  0.502485    0.698198  1.090670  0.041773    1.192320
# 3            0.719689  0.502485    0.784943  1.090670  0.041773    1.303425
#
#    zhangs_metric
# 0       0.338634
# 1       0.260194
# 2       0.296570
# 3       0.231022

# %%
dataset.head()
# Out:
#    department1  department2  department3  department4  department5  \
# 0        False        False        False        False        False
# 1         True        False        False        False        False
# 2        False        False        False        False        False
# 3         True        False        False        False        False
# 4        False        False        False        False        False
#
#    department6  department7  department8  department9  'grocery misc'  ...  \
# 0        False        False        False        False           False  ...
# 1        False        False        False        False           False  ...
# 2        False        False        False        False           False  ...
# 3        False        False        False        False           False  ...
# 4        False        False        False        False           False  ...
#
#    department209  department210  department211  department212  department213  \
# ...
